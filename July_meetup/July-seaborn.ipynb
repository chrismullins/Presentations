# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
Check out these vids: https://www.youtube.com/watch?v=-Lt7kpTM-v8&list=PLgJhDSE2ZLxYlhQx0UfVlnF1F7OWF-9rp&index=4

# %%
ls
# Out:
# iris.csv  seaborn-venv-py36/  tips.csv  Untitled.ipynb

# %%
tips = pd.read_csv("tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Distplot: histogram + KDE

# %%
sns.distplot(tips.total_bill)

# %%
sns.distplot(tips.total_bill, rug=True, hist=True, kde=True)

# %%
sns.distplot(tips.total_bill, rug=True, hist=True, kde=False, norm_hist=False)

# %%
from scipy import stats
sns.distplot(tips.total_bill, rug=True, hist=True, kde=True, fit=stats.gamma)

# %%
ax = sns.kdeplot(tips.total_bill)

# %%
ax = sns.kdeplot(tips.total_bill, shade=True)

# %%
ax = sns.kdeplot(tips.total_bill, tips.tip)

# %%
ax = sns.kdeplot(tips.total_bill, tips.tip, shade=True)

# %%
ax = sns.kdeplot(tips.total_bill, tips.tip, n_levels=20)

# %% [markdown]
# ### More of the KDE Plot

# %%
# Make sure you pip install statsmodels for this
ax = sns.kdeplot(tips.total_bill, cumulative=True)

# %%
ax = sns.kdeplot(tips.total_bill, gridsize=4)

# %%
ax = sns.kdeplot(tips.total_bill, cut=0)

# %%
ax = sns.kdeplot(tips.total_bill, clip=(0,30))

# %% [markdown]
# Note that the *KDE* can go past 30, but it only considers datapoints inside the cut.

# %%
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["species"].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
sns.jointplot(data=iris, x="sepal_length", y="sepal_width")

# %%
sns.set_style("darkgrid")

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", size=10)

# %%
import matplotlib.pyplot as plt
sns.FacetGrid(data=iris, hue="species", size=8).map(plt.scatter, "sepal_length", "sepal_width").add_legend()

# %%
sns.boxplot(data=iris, x = "species", y = "petal_length")

# %%
sns.violinplot(data=iris, x = "species", y = "petal_length", size=6)

# %% [markdown]
# ### Pairplot: shows joint and marginal distributions

# %%
g = sns.pairplot(data=iris, kind="scatter")

# %%
g = sns.pairplot(data=iris, kind="scatter", hue="species")

# %%
g = sns.pairplot(data=iris, kind="scatter", hue="species", markers=['o', 's', 'D'])

# %%
g = sns.pairplot(data=iris, kind="scatter", 
                x_vars=["sepal_length", "sepal_width"],
                y_vars=["petal_length", "petal_width"])

# %%
g = sns.pairplot(data=iris, kind="scatter", 
                diag_kind="kde")

# %%
g = sns.pairplot(data=iris, kind="reg")

# %%
g = sns.pairplot(data=iris, kind="reg", hue="species", diag_kind="kde")

# %% [markdown]
# ### Strip and swarm plots

# %%
ax = sns.stripplot(x=tips.total_bill)

# %%
ax = sns.stripplot(x=tips.day, y = tips.total_bill)

# %%
tips["day"] = tips["day"].astype('category')
tips["day"].categories = ['Thur', 'Fri', 'Sat', 'Sun']
tips["day"].ordered = True

# %%
ax = sns.stripplot(x=tips.day, y = tips.total_bill)

# %%
ax = sns.stripplot(x=tips.day, y = tips.total_bill, jitter=True)

# %%
ax = sns.stripplot(x=tips.day, y = tips.total_bill, jitter=0.05)

# %%
ax = sns.stripplot(x=tips.total_bill, y=tips.day, jitter=True)

# %%
ax = sns.stripplot(x=tips.sex, y=tips.total_bill, hue=tips.day, jitter=True)

# %%
ax = sns.stripplot(x=tips.day, y=tips.total_bill, hue=tips.sex, jitter=True)

# %%
ax = sns.stripplot(x=tips.day, y=tips.total_bill, hue=tips.smoker, jitter=True, dodge=True)

# %% [markdown]
# NB: in older version, `dodge` was called `split` which makes more sense to me but I guess could be ambiguous?

# %%
ax = sns.boxplot(x=tips.tip, y=tips.day, whis=np.inf)
ax = sns.stripplot(x=tips.tip, y=tips.day, jitter=True, color=".3")

# %%
ax = sns.swarmplot(x=tips.day, y=tips.total_bill, hue=tips.smoker, 
                  palette="Set2", dodge=True)

# %% [markdown]
# ### Box plots

# %%
ax = sns.boxplot(x=tips.total_bill)

# %%
ax = sns.boxplot(x=tips.total_bill, notch=True)

# %%
ax = sns.boxplot(x=tips.total_bill, notch=True, whis=2)

# %%
ax = sns.boxplot(x=tips.day, y=tips.total_bill, notch=False)

# %%
ax = sns.boxplot(x=tips.day, y=tips.total_bill, hue=tips.smoker, palette="Set3")

# %% [markdown]
# ### Joint Plot

# %%
g = sns.jointplot(x=tips.total_bill, y=tips.tip)

# %%
g = sns.jointplot(x=tips.total_bill, y=tips.tip, kind='reg')

# %%
g = sns.jointplot(x=tips.total_bill, y=tips.tip, kind='hex')

# %%
g = sns.jointplot(x=tips.total_bill, y=tips.tip, kind='kde')

# %%
from scipy.stats import spearmanr
g = sns.jointplot(tips.total_bill, tips.tip, stat_func=spearmanr)

# %%
g = (sns.jointplot(tips.total_bill, tips.tip)
     .plot_joint(sns.kdeplot, n_levels=6)
     .plot_marginals(sns.rugplot))

# %% [markdown]
# ### Violin plots

# %%
ax = sns.violinplot(tips.total_bill, inner="box")

# %%
ax = sns.violinplot(tips.total_bill, inner="quartile")

# %%
ax = sns.violinplot(tips.total_bill, inner="stick")

# %%
ax = sns.violinplot(tips.total_bill, inner="point")

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill, scale='area')

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill, scale='width')

# %% [markdown]
# The real one you want to use is `count`.

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill, scale='count')

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill, hue=tips.smoker, palette='muted')

# %% [markdown]
# Be careful below, violinplot actually does use `split`.

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill, hue=tips.smoker, palette='muted', split=True)

# %% [markdown]
# ### LM (Linear Model) Plot

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip")

# %% [markdown]
# Looks like this one needs you to specify the `data` variable.

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip", col="smoker")

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip", row="sex", col="time")

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip", row="sex", col="time", hue="smoker")

# %%
g = sns.lmplot(data=tips, x="size", y="tip")

# %%
g = sns.lmplot(data=tips, x="size", y="tip", x_jitter=0.05)

# %%
g = sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean)

# %%
g = sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean, x_ci=50)

# %%
g = sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean, x_ci=50, ci=20)

# %%
g = sns.lmplot(data=tips, x="total_bill", y="tip", x_bins=10)

# %% [markdown]
# ## Load the anscombe quartet dataset

# %%
anscombe = pd.read_csv("anscombe.csv")
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"), ci=None, scatter_kws={"s": 80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), 
           ci=None, scatter_kws={"s": 80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), 
           order=2, ci=None, scatter_kws={"s": 80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), 
           ci=None, scatter_kws={"s": 80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), 
           robust=True, ci=None, scatter_kws={"s": 80})

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > 0.15
sns.lmplot(x="total_bill", y="big_tip", data=tips, y_jitter=0.03)

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > 0.15
sns.lmplot(x="total_bill", y="big_tip", data=tips, y_jitter=0.03, logistic=True)

# %% [markdown]
# #### Locally weighted linear regression

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, lowess=True)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, logx=True)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, logx=True, truncate=True)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, logx=True, truncate=True, x_partial="size")
# Out:
# /home/chris/Projects/seaborn/seaborn-venv-py36/lib/python3.6/site-packages/seaborn/regression.py:313: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return (a_prime + a_mean).reshape(a.shape)

# %% [markdown]
# ### Other regressions

# %%
g = sns.residplot(x="total_bill", y="tip", data=tips)

# %%
g = sns.residplot(x="total_bill", y="tip", data=tips, lowess=True)

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"))

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), order=2)

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'III'"))

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), robust=True)

# %%
sns.coefplot("tip ~ total_bill + C(day)", data=tips, intercept=True, ci=90)
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# <ipython-input-113-5e46eef8319e> in <module>()
# ----> 1 sns.coefplot("tip ~ total_bill + C(day)", data=tips, intercept=True, ci=90)
#
# AttributeError: module 'seaborn' has no attribute 'coefplot'

# %% [markdown]
# ### Point, Bar, and Count plot

# %%
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
tips["time"] = tips["time"].astype('category')

# %%
tips["time"].categories = ["Lunch", "Dinner"]
tips["time"].ordered = True

# %%
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker", dodge=True, data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips,
                  dodge=True, markers=['o', 'x'], linestyles=['-','--'])

# %%
ax = sns.pointplot(x="tip", y="day", data=tips)

# %%
ax = sns.pointplot(x="tip", y="day", data=tips, join=False)

# %%
ax = sns.pointplot(x="day", y="tip", data=tips, estimator=np.median)

# %%
ax = sns.pointplot(x="day", y="tip", data=tips, estimator=np.median, ci=95, capsize=0.2)

# %%
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
ax = sns.countplot(x="day", hue="sex", data=tips)

# %% [markdown]
# ### Factor Plot

# %%
g = sns.factorplot(x="day", y="total_bill", hue="sex", data=tips, dodge=True)

# %%
g = sns.factorplot(x="day", y="total_bill", hue="sex",
                  data=tips, kind="violin", scale="count")

# %%
g = sns.factorplot(x="day", y="total_bill", hue="sex",
                  data=tips, kind="violin", scale="count",
                  col="time")
# Out:
# /home/chris/Projects/seaborn/seaborn-venv-py36/lib/python3.6/site-packages/seaborn/categorical.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   scaler = count / counts[i].max()

# %% [markdown]
# Let's use the Titanic dataset.

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
g = sns.factorplot(x='age', y='embark_town',
                  hue='sex', row='class',
                  data=titanic,
                  orient='h', size=2, aspect=3.5, palette='Set3',
                  kind='violin', split=True, cut=0, bw=.2)

# %%
g = sns.factorplot(x='age', y='embark_town', 
                  hue='who', row='class', col='sex',
                  data=titanic,
                  orient='h', size=2, aspect=3.5, palette='Set3',
                  kind='box')

# %% [markdown]
# ### Heatmaps

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
ax = sns.heatmap(uniform_data, vmin=0, vmax=1, cmap='Blues', robust=True)

# %%
normal_data = np.random.randn(10,12)
ax = sns.heatmap(normal_data, cmap='Blues')

# %%
ax = sns.heatmap(normal_data, cmap='coolwarm')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot('month', 'year', 'passengers')
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, cmap='Blues')

# %%
ax = sns.heatmap(flights, cmap='Blues', annot=True, fmt='d')
